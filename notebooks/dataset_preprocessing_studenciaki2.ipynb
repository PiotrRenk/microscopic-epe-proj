# %%
import pandas as pd

# %%
df = pd.read_excel('.././materials/Studenciaki 2 safe.xlsx')

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1           Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0       Wiek   Telefon                  Data  PSA (ng/ml)
#   PSA DT (msc)
# 1        NaN        NaN                  NaN           NaN           NaN
# 2        NaN        NaN  2024-10-18 00:00:00           3.7           6.6
# 3        NaN        NaN  2024-10-18 00:00:00          0.96           NaN
# 4        NaN        NaN  2024-10-24 00:00:00          4.25          46.6
#
#     Unnamed: 5                       Unnamed: 6      Unnamed: 7 Unnamed: 8  \
# 0  PSA density  DRE 0-prawidłowe 1-patologiczne  cTNM
# tylko cT         cN
# 1          NaN                              NaN             NaN        NaN
# 2          NaN                                1             T2a        NaN
# 3          NaN                                0               -        NaN
# 4          NaN                                0              T1        NaN
#
#                                           Unnamed: 9  ...   Unnamed: 60  \
# 0  Bx 1-pierwszorazowa 2-drugi raz 3-trzeci i kol...  ...  EPE strona P
# 1                                                NaN  ...           NaN
# 2                                                NaN  ...           NaN
# 3                                                NaN  ...           NaN
# 4                                                NaN  ...           NaN
#
#     Unnamed: 61     Unnamed: 62 Unnamed: 63    Unnamed: 64   Unnamed: 65  \
# 0  EPE strona L  EPE strony P+L     SVI
# 0/1  SVI
# strona P  SVI strona
# L
# 1           NaN             NaN         NaN            NaN           NaN
# 2           NaN             NaN         NaN            NaN           NaN
# 3           NaN             NaN         NaN            NaN           NaN
# 4           NaN             NaN         NaN            NaN           NaN
#
#       Unnamed: 66    Unnamed: 67 Unnamed: 68 Unnamed: 69
# 0  SVI strony P+L  PSA po 6 tyg     Operator     Patolog
# 1             NaN            NaN         NaN         NaN
# 2             NaN            NaN          MS          PK
# 3             NaN            NaN          AD          PK
# 4             NaN            NaN          MS          KB
#
# [5 rows x 70 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
#        'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61',
#        'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65',
#        'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69'],
#       dtype='object')

# %%
df.columns = df.iloc[0]

# %%
df.columns
# Out:
# Index(['Wiek', 'Telefon ', 'Data', 'PSA (ng/ml)
# ', 'PSA DT (msc)',
#        'PSA density', 'DRE 0-prawidłowe 1-patologiczne', 'cTNM
# tylko cT',
#        'cN', 'Bx 1-pierwszorazowa 2-drugi raz 3-trzeci i kolejny raz',
#        'Typ Bx
# 0-celowana
# 1-cel+regionalna
# 2-pełna
# 3-tylko systematyczna
# 4 - celowana + regio + systematyczna kontralateralna do IL',
#        'zmiana nr 1\nmpMRI PIRADS
# zmiana (dominująca IL)',
#        'Lokalizacja zmiany nr 1
# apex/mid/base',
#        'Lokalizacja zmiany nr 1 PL/PP', 'Lokalizacja zmiany nr1
# [PIRADS map]',
#        'Objętość zmiany
# (ml) nr 1 ', 'Maks wymiar IL w mpMRI',
#        'Zmiana nr 1\nGleason ', 'Zmiana nr 1\nISUP ',
#        '% badanego materiału nr 1', 'Gleason
# Strefy obwodowej IL ',
#        'ISUP
# strefy obwodowej IL', '% badanego materiału strefy obwodowej IL',
#        'zmiana nr 2\nmpMRI PIRADS', 'Lokalizacja zmiany nr 2
# apex/mid/base',
#        'Lokalizacja zmiany nr 2 PL/PP', 'Lokalizacja zmiany nr2
# [PIRADS map]',
#        'Objętość zmiany
# (ml) nr 2 ', 'Zmiana nr 2\nGleason ',
#        'Zmiana nr 2\nISUP ', '% badanego materiału nr 2',
#        'zmiana nr 3\nmpMRI PIRADS', 'Lokalizacja zmiany nr 3
# apex/mid/base',
#        'Lokalizacja zmiany nr 3 PL/PP', 'Lokalizacja zmiany nr 3
# [PIRADS map]',
#        'Objętość zmiany
# (ml) nr 3', 'Zmiana nr 3\nGleason ',
#        'Zmiana nr 3\nISUP ', '% badanego materiału nr 3',
#        'REGION IL\nGleason ', 'REGION IL\nISUP ', '% badanego REGION IL',
#        'iTNM', 'Obj. Stercza
# [ml]', 'EPE w MRI 0-TAK 1-NIE',
#        'EPE który płat P/L/PL', 'Objętość wszystkich zmian [ml]',
#        'Bx
# CEL+
# IL', 'Bx
# REG+', 'Bx
# CEL+
# inne zmiany', 'Bx SYS+',
#        'Prostatektomia w USK 1-Tak 0-Nie', 'Typ leczenia ', 'Gleason post.op',
#        'ISUP post. Op', 'pT', 'pN', 'pM', 'pR
# 0/1', 'EPE
# 0/1', 'EPE strona P',
#        'EPE strona L', 'EPE strony P+L', 'SVI
# 0/1', 'SVI
# strona P',
#        'SVI strona
# L', 'SVI strony P+L', 'PSA po 6 tyg ', 'Operator',
#        'Patolog'],
#       dtype='object', name=0)

# %%
df.shape
# Out:
# (78, 70)

# %%
non_null_count = df.isnull().sum()

threshold = 59

columns_with_many_missing = non_null_count[non_null_count > threshold]
print(df["Telefon "])
#print(df["SVI strona L"])
print(columns_with_many_missing)
columns_with_many_missing.count()
# Out:
# 0     Telefon
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 73         NaN
# 74         NaN
# 75         NaN
# 76         NaN
# 77         NaN
# Name: Telefon , Length: 78, dtype: object
# 0
# Telefon                                     77
# PSA DT (msc)                                69
# Objętość zmiany(ml) nr 1                   74
# GleasonStrefy obwodowej IL                 77
# ISUP strefy obwodowej IL                   77
# % badanego materiału strefy obwodowej IL    77
# Lokalizacja zmiany nr 2apex/mid/base       65
# Lokalizacja zmiany nr 2 PL/PP               61
# Lokalizacja zmiany nr2[PIRADS map]         61
# Objętość zmiany(ml) nr 2                   76
# Zmiana nr 2\nGleason                        69
# Zmiana nr 2\nISUP                           69
# % badanego materiału nr 2                   71
# zmiana nr 3\nmpMRI PIRADS                   74
# Lokalizacja zmiany nr 3apex/mid/base       74
# Lokalizacja zmiany nr 3 PL/PP               74
# Lokalizacja zmiany nr 3[PIRADS map]        74
# Objętość zmiany(ml) nr 3                   74
# Zmiana nr 3\nGleason                        74
# Zmiana nr 3\nISUP                           74
# % badanego materiału nr 3                   74
# REGION IL\nGleason                          77
# REGION IL\nISUP                             77
# % badanego REGION IL                        77
# iTNM                                        71
# EPE który płat P/L/PL                       71
# Objętość wszystkich zmian [ml]              77
# Bx CEL+IL                                 77
# Bx REG+                                    77
# BxCEL+inne zmiany                         77
# Bx SYS+                                     77
# SVI strona P                               70
# SVI stronaL                                70
# SVI strony P+L                              67
# PSA po 6 tyg                                77
# dtype: int64
# 35

# %%
df.drop(columns = columns_with_many_missing.index, inplace=True)

# %%
df.shape
# Out:
# (78, 35)

# %%
df.isnull().sum()
# Out:
# 0
# Wiek                                                                                                                                9
# Data                                                                                                                                1
# PSA (ng/ml)
#                                                                                                                         5
# PSA density                                                                                                                        14
# DRE 0-prawidłowe 1-patologiczne                                                                                                    11
# cTNM
# tylko cT                                                                                                                     11
# cN                                                                                                                                 26
# Bx 1-pierwszorazowa 2-drugi raz 3-trzeci i kolejny raz                                                                             10
# Typ Bx
# 0-celowana
# 1-cel+regionalna
# 2-pełna
# 3-tylko systematyczna
# 4 - celowana + regio + systematyczna kontralateralna do IL    59
# zmiana nr 1\nmpMRI PIRADS
# zmiana (dominująca IL)                                                                                    8
# Lokalizacja zmiany nr 1
# apex/mid/base                                                                                              26
# Lokalizacja zmiany nr 1 PL/PP                                                                                                      17
# Lokalizacja zmiany nr1
# [PIRADS map]                                                                                                19
# Maks wymiar IL w mpMRI                                                                                                             18
# Zmiana nr 1\nGleason                                                                                                                5
# Zmiana nr 1\nISUP                                                                                                                   5
# % badanego materiału nr 1                                                                                                          21
# zmiana nr 2\nmpMRI PIRADS                                                                                                          59
# Obj. Stercza
# [ml]                                                                                                                 11
# EPE w MRI 0-TAK 1-NIE                                                                                                              44
# Prostatektomia w USK 1-Tak 0-Nie                                                                                                    9
# Typ leczenia                                                                                                                        8
# Gleason post.op                                                                                                                    10
# ISUP post. Op                                                                                                                      10
# pT                                                                                                                                 11
# pN                                                                                                                                 11
# pM                                                                                                                                  9
# pR
# 0/1                                                                                                                             10
# EPE
# 0/1                                                                                                                            13
# EPE strona P                                                                                                                       57
# EPE strona L                                                                                                                       57
# EPE strony P+L                                                                                                                     48
# SVI
# 0/1                                                                                                                            10
# Operator                                                                                                                            7
# Patolog                                                                                                                             6
# dtype: int64

# %%
mask = df.isnull().sum() > 0
print(df.columns[mask])
print(df.dtypes)
numeric_columns = df.select_dtypes(include=['int64', 'float64']) 
print(numeric_columns.columns)
numerical_and_mask = numeric_columns.columns.intersection(df.columns[mask])
print(numerical_and_mask)
# Out:
# Index(['Wiek', 'Data', 'PSA (ng/ml)', 'PSA density',
#        'DRE 0-prawidłowe 1-patologiczne', 'cTNM tylko cT', 'cN',
#        'Bx 1-pierwszorazowa 2-drugi raz 3-trzeci i kolejny raz',
#        'Typ Bx 0-celowana 1-cel+regionalna 2-pełna 3-tylko systematyczna4 - celowana + regio + systematyczna kontralateralna do IL',
#        'zmiana nr 1\nmpMRI PIRADSzmiana (dominująca IL)',
#        'Lokalizacja zmiany nr 1apex/mid/base',
#        'Lokalizacja zmiany nr 1 PL/PP', 'Lokalizacja zmiany nr1[PIRADS map]',
#        'Maks wymiar IL w mpMRI', 'Zmiana nr 1\nGleason ', 'Zmiana nr 1\nISUP ',
#        '% badanego materiału nr 1', 'zmiana nr 2\nmpMRI PIRADS',
#        'Obj. Stercza [ml]', 'EPE w MRI 0-TAK 1-NIE',
#        'Prostatektomia w USK 1-Tak 0-Nie', 'Typ leczenia ', 'Gleason post.op',
#        'ISUP post. Op', 'pT', 'pN', 'pM', 'pR0/1', 'EPE0/1', 'EPE strona P',
#        'EPE strona L', 'EPE strony P+L', 'SVI0/1', 'Operator', 'Patolog'],
#       dtype='object', name=0)
# 0
# Wiek                                                                                                                               object
# Data                                                                                                                               object
# PSA (ng/ml)                                                                                                                       object
# PSA density                                                                                                                        object
# DRE 0-prawidłowe 1-patologiczne                                                                                                    object
# cTNM tylko cT                                                                                                                     object
# cN                                                                                                                                 object
# Bx 1-pierwszorazowa 2-drugi raz 3-trzeci i kolejny raz                                                                             object
# Typ Bx 0-celowana 1-cel+regionalna 2-pełna 3-tylko systematyczna4 - celowana + regio + systematyczna kontralateralna do IL    object
# zmiana nr 1\nmpMRI PIRADSzmiana (dominująca IL)                                                                                   object
# Lokalizacja zmiany nr 1apex/mid/base                                                                                              object
# Lokalizacja zmiany nr 1 PL/PP                                                                                                      object
# Lokalizacja zmiany nr1[PIRADS map]                                                                                                object
# Maks wymiar IL w mpMRI                                                                                                             object
# Zmiana nr 1\nGleason                                                                                                               object
# Zmiana nr 1\nISUP                                                                                                                  object
# % badanego materiału nr 1                                                                                                          object
# zmiana nr 2\nmpMRI PIRADS                                                                                                          object
# Obj. Stercza [ml]                                                                                                                 object
# EPE w MRI 0-TAK 1-NIE                                                                                                              object
# Prostatektomia w USK 1-Tak 0-Nie                                                                                                   object
# Typ leczenia                                                                                                                       object
# Gleason post.op                                                                                                                    object
# ISUP post. Op                                                                                                                      object
# pT                                                                                                                                 object
# pN                                                                                                                                 object
# pM                                                                                                                                 object
# pR0/1                                                                                                                             object
# EPE0/1                                                                                                                            object
# EPE strona P                                                                                                                       object
# EPE strona L                                                                                                                       object
# EPE strony P+L                                                                                                                     object
# SVI0/1                                                                                                                            object
# Operator                                                                                                                           object
# Patolog                                                                                                                            object
# dtype: object
# Index([], dtype='object', name=0)
# Index([], dtype='object', name=0)

# %%
df.fillna(df[numerical_and_mask].mean(), inplace=True)
df.isnull().sum()
